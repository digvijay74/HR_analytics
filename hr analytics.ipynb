# %%
import pandas as pd

# %%
df = pd.read_csv('employees.csv',skipinitialspace = True)

# %%
df.head(2)
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium

# %%
People Charm’, a growing company is facing a high attrition rate among
their employees which in turn affects their business due to lack of expertise
and experience.
• Their HR department is assigned the task to reduce the attrition rate by
retaining employees who are about to churn out.
• They need to recommend special plans or strategies which will help them to
retain their employees which in turn will help them to grow bigger as a
company

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
# data preprocessing:
df.columns
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
df.isnull().sum() # to get the number of missing vals for each and every cols:
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
# in our datasets we have no missinng vals but if it was we can drop using drop na:

# %%
# working with the duplicate records:
df[df.duplicated()]
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 263                 0.46            0.57                 2              139
# 877                 0.37            0.51                 2              127
# 974                 0.42            0.53                 2              142
# 1017                0.40            0.50                 2              127
# 1241                0.10            0.85                 6              266
# ...                  ...             ...               ...              ...
# 14985               0.95            0.84                 3              270
# 14987               0.37            0.45                 2              126
# 14988               0.43            0.57                 2              157
# 14993               0.61            0.89                 3              242
# 14994               0.11            0.85                 7              275
#
# ...

# %%
# remove duplictaed rows which has alll the rows same vals:

df = df.drop_duplicates()

# %%
df.shape
# Out:
# (11991, 10)

# %%
# correlation matrix: seeing how cols are related to each other:
# positive corr: when 2 cols directly prop. 
# negative corr: when 2 cols are inversely prop:
# zero corr: when cols are not related with each other
# corr values lie in -1 to +1: 
df.corr()
# Out:
#                        satisfactoryLevel  lastEvaluation  numberOfProjects  \
# satisfactoryLevel               1.000000        0.095186         -0.133246
# lastEvaluation                  0.095186        1.000000          0.270256
# numberOfProjects               -0.133246        0.270256          1.000000
# avgMonthlyHours                -0.006252        0.264678          0.331516
# timeSpent.company              -0.152915        0.096829          0.188837
# workAccident                    0.039940       -0.005695         -0.005612
# left                           -0.350558        0.013520          0.030928
# promotionInLast5years           0.019789       -0.007206         -0.000544
#
#                        avgMonthlyHours  timeSpent.company  workAccident  \
# satisfactoryLevel            -0.006252          -0.152915      0.039940
# lastEvaluation                0.264678           0.096829     -0.005695
# numberOfProjects              0.331516           0.188837     -0.005612
# ...

# %%
import matplotlib.pyplot as plt

import seaborn as sns
sns.heatmap(df.corr(),annot = True)
plt.show()

# %%
df.head(1)
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept salary
# 0                  3             0     1                      0  sales    low

# %%
a = ['dept','numberOfProjects','timeSpent.company','workAccident','promotionInLast5years','salary']
a
# Out:
# ['dept',
#  'numberOfProjects',
#  'timeSpent.company',
#  'workAccident',
#  'promotionInLast5years',
#  'salary']

# %%
import matplotlib.pyplot as ply
fig = plt.subplots(figsize=(20,25))

for i,j in enumerate(a):# extract index for i and then values for j:
    plt.subplot(3,2,i+1)
    plt.subplots_adjust(hspace = 1.0)# as "i" will be containing index values:
    sns.countplot(x=j,data = df,hue = 'left')
    plt.xticks(rotation = 90)
   
  
plt.show()

# %%
# dept : 'sales','technical'"support":
#no_ofproject: 2,7:******
#timespentcompany:3 ,4,5**********
#workaccident:
#promotionlast5year: 0 so their are no promotions *********
#salary: low and medium salary************
